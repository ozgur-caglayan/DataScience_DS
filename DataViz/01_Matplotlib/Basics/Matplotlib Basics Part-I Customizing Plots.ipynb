# %% [markdown]
# # Matplotlib Basics Part-I

# %% [markdown]
# # Customizing Plots

# %% [markdown]
# * https://www.datacamp.com/courses/introduction-to-data-visualization-with-python

# %% [markdown]
# ## Importing Libraries and Dataset

# %%
% matplotlib inline
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
women_degrees_df = pd.read_csv('percent-bachelors-degrees-women-usa.csv')

# %%
df1 = women_degrees_df
df1.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
df1.columns
# Out:
# Index(['Year', 'Agriculture', 'Architecture', 'Art and Performance', 'Biology',
#        'Business', 'Communications and Journalism', 'Computer Science',
#        'Education', 'Engineering', 'English', 'Foreign Languages',
#        'Health Professions', 'Math and Statistics', 'Physical Sciences',
#        'Psychology', 'Public Administration', 'Social Sciences and History'],
#       dtype='object')

# %% [markdown]
# ## 1. Multiple plots on single axis

# %%
# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(df1.Year, df1['Computer Science'], color='red')
# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(df1.Year, df1['Physical Sciences'], color = 'blue')
# Display the plot
plt.show()

# %% [markdown]
# ## 2. Using axes()

# %% [markdown]
# Remember to pass these coordinates to plt.axes() in the form of a list: [xlo, ylo, width, height].

# %%
plt.axes([0.05, 0.05, 0.425, 0.9])

# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(df1.Year, df1['Physical Sciences'], color = 'blue')

# Create plot axes for the second line plot
plt.axes([0.525, 0.05, 0.425, 0.9])

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(df1.Year, df1['Computer Science'], color='red')

# Display the plot
plt.show()

# %% [markdown]
# ## 3. Using subplot() (1)

# %%
# Create a figure with 1x2 subplot and make the left subplot active (plots will be showed as 1 row and 2 column, and below is 1st)
plt.subplot(1, 2, 1)

# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(df1.Year, df1['Physical Sciences'], color = 'blue')
plt.title('Physical Sciences')

# Make the right subplot active in the current 1x2 subplot grid (plots will be showed as 1 row and 2 column, and below is 2nd)
plt.subplot(1, 2, 2)

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(df1.Year, df1['Computer Science'], color='red')
plt.title('Computer Science')

# Use plt.tight_layout() to improve the spacing between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Using subplot() (2)

# %%
# Create a figure with 2x2 subplot layout and make the top left subplot active
plt.subplot(2, 2, 1)

# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(df1.Year, df1['Physical Sciences'], color = 'blue')
plt.title('Physical Sciences')

# Make the top right subplot active in the current 2x2 subplot grid 
plt.subplot(2, 2, 2)

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(df1.Year, df1['Computer Science'], color='red')
plt.title('Computer Science')

# Make the bottom left subplot active in the current 2x2 subplot grid
plt.subplot(2, 2, 3)

# Plot in green the % of degrees awarded to women in Health Professions
plt.plot(df1.Year, df1['Health Professions'], color='green')
plt.title('Health Professions')

# Make the bottom right subplot active in the current 2x2 subplot grid
plt.subplot(2, 2, 4)

# Plot in yellow the % of degrees awarded to women in Education
plt.plot(df1.Year, df1['Education'], color='yellow')
plt.title('Education')

# Improve the spacing between subplots and display them
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Using xlim(), ylim()

# %%
# Plot the % of degrees awarded to women in Computer Science and the Physical Sciences
plt.plot(df1.Year, df1['Computer Science'], color='red')
plt.plot(df1.Year, df1['Physical Sciences'], color = 'blue')

# Add the axis labels
plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

# Set the x-axis range
plt.xlim((1990,2010)) 

# Set the y-axis range
plt.ylim((0,50))

# Add a title and display the plot
plt.title('Degrees awarded to women (1990-2010)\nComputer Science (red)\nPhysical Sciences (blue)')
plt.show()

# Save the image as 'xlim_and_ylim.png'
plt.savefig('xlim_and_ylim.png')

# %% [markdown]
# ## 6. Using axis()

# %%
# Plot in blue the % of degrees awarded to women in Computer Science
plt.plot(df1.Year, df1['Computer Science'], color='blue')

# Plot in red the % of degrees awarded to women in the Physical Sciences
plt.plot(df1.Year, df1['Physical Sciences'], color='red')

# Set the x-axis and y-axis limits
plt.axis((1990, 2010, 0, 50))

# Show the figure
plt.show()

# Save the figure as 'axis_limits.png'
plt.savefig('axis_limits.png')

# %% [markdown]
# ## 7. Using legend()

# %% [markdown]
# Legends are useful for distinguishing between multiple datasets displayed on common axes. The relevant data are created using specific line colors or markers in various plot commands. Using the keyword argument label in the plotting function associates a string to use in a legend.

# %%
# Specify the label 'Computer Science'
plt.plot(df1.Year, df1['Computer Science'], color='blue', label='Computer Science') 

# Specify the label 'Physical Sciences' 
plt.plot(df1.Year, df1['Physical Sciences'], color='red', label='Physical Sciences')

# Add a legend at the lower center
plt.legend(loc='lower center')

# Add axis labels and title
plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
plt.show()

# %% [markdown]
# ## 8. Using annotate()

# %% [markdown]
# It is often useful to annotate a simple plot to provide context. This makes the plot more readable and can highlight specific aspects of the data. Annotations like text and arrows can be used to emphasize specific observations.

# %%
# Plot with legend as before
plt.plot(df1.Year, df1['Computer Science'], color='red', label='Computer Science') 
plt.plot(df1.Year, df1['Physical Sciences'], color='blue', label='Physical Sciences')
plt.legend(loc='lower right')

# Compute the maximum enrollment of women in Computer Science: cs_max
cs_max = df1['Computer Science'].max()

# Calculate the year in which there was maximum enrollment of women in Computer Science: yr_max
yr_max = df1.Year[df1['Computer Science'].values.argmax()]

# Add a black arrow annotation
plt.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max+5, cs_max+5), arrowprops=dict(facecolor='black'))

# Add axis labels and title
plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')
# Out:
# Text(0.5,1,'Undergraduate enrollment of women')

# %% [markdown]
# ## 9. Modifying Styles

# %% [markdown]
# Matplotlib comes with a number of different stylesheets to customize the overall look of different plots. To activate a particular stylesheet you can simply call plt.style.use() with the name of the style sheet you want. To list all the available style sheets you can execute: print(plt.style.available).

# %%
# Set the style to 'ggplot'
plt.style.use('ggplot')

# Create a figure with 2x2 subplot layout
plt.subplot(2, 2, 1) 

# Plot the enrollment % of women in the Physical Sciences
plt.plot(df1.Year, df1['Physical Sciences'], color='blue')
plt.title('Physical Sciences')

# Plot the enrollment % of women in Computer Science
plt.subplot(2, 2, 2)
plt.plot(df1.Year, df1['Computer Science'], color='red')
plt.title('Computer Science')

# Add annotation
cs_max = df1['Computer Science'].max()
yr_max = df1.Year[df1['Computer Science'].values.argmax()]
plt.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max+5, cs_max+5), arrowprops=dict(facecolor='black'))

# Plot the enrollmment % of women in Health professions
plt.subplot(2, 2, 3)
plt.plot(df1.Year, df1['Health Professions'], color='green')
plt.title('Health Professions')

# Plot the enrollment % of women in Education
plt.subplot(2, 2, 4)
plt.plot(df1.Year, df1['Education'], color='yellow')
plt.title('Education')

# Improve spacing between subplots and display them
plt.tight_layout()
plt.show()

# %%
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']
