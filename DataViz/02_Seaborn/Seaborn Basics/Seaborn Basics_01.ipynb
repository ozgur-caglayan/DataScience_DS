# %% [markdown]
# # SEABORN INTRODUCTION

# %% [markdown]
# https://www.datacamp.com/courses/data-visualization-with-seaborn

# %% [markdown]
# ## 1. Reading a csv file

# %% [markdown]
# This first step in most data analysis is to import pandas and seaborn and read a data file in order to analyze it further.

# %%
# import all modules
% matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read in the DataFrame
df = pd.read_csv('auto-mpg.csv')
df.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang    red
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d  green
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc   blue
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada    red
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000   blue
#
#         size marker
# 0  27.370336      o
# 1  62.199511      o
# 2   9.000000      x
# 3  34.515625      o
# 4  13.298178      s

# %% [markdown]
# ## 2. Comparing a histogram and distplot

# %% [markdown]
# The pandas library supports simple plotting of data, which is very convenient when data is already likely to be in a pandas DataFrame.
#
# Seaborn generally does more statistical analysis on data and can provide more sophisticated insight into the data. In this exercise, we will compare a pandas histogram vs the seaborn distplot.

# %% [markdown]
# * Use the pandas' plot.hist() function to plot a histogram of the yr column.

# %%
# Display pandas histogram
df['yr'].plot.hist()
plt.show()

# Clear out the pandas histogram
plt.clf()

# %% [markdown]
# * Use Seaborn's distplot() function to plot a distribution plot of the same column.

# %%
# Display a Seaborn distplot
sns.distplot(df['yr'])
plt.show()

# Clear the distplot
plt.clf()

# %% [markdown]
# ## 3. Plot a histogram

# %% [markdown]
# The distplot() function will return a Kernel Density Estimate (KDE) by default.
#
# The KDE helps to smooth the distribution and is a useful way to look at the data. However, Seaborn can also support the more standard histogram approach if that is more meaningful for your analysis.

# %% [markdown]
# Create a distplot for the data and disable the KDE.
# Explicitly pass in the number 20 for the number of bins in the histogram.
# Display the plot using plt.show().

# %%
# Create a distplot
sns.distplot(df['yr'], kde=False, bins=20)

# Display the plot
plt.show()

# %% [markdown]
# Create a distplot for the data and do not disable the KDE.

# %%
# Create a distplot
sns.distplot(df['yr'], bins=20)

# Display the plot
plt.show()

# %% [markdown]
# ## 4. Rug plot and kde shading

# %% [markdown]
# Now that you understand some function arguments for distplot(), we can continue further refining the output. This process of creating a visualization and updating it in an incremental fashion is a useful and common approach to look at data from multiple perspectives.
#
# Seaborn excels at making this process simple.

# %%
# Create a distplot of the Award Amount
sns.distplot(df['yr'], hist=False, rug=True, kde_kws={'shade':True})

# Plot the results
plt.show()

# %%
# Create a distplot of the Award Amount
sns.distplot(df['yr'], hist=False, kde_kws={'shade':True})

# Plot the results
plt.show()

# %%
# Create a distplot of the Award Amount
sns.distplot(df['yr'], hist=False )

# Plot the results
plt.show()

# %% [markdown]
# ## 5. Creating a regression plot

# %% [markdown]
# Create a regression plot using regplot().

# %%
sns.regplot(data=df,
         x="mpg",
         y="hp")

# Display the plot
plt.show()

# %% [markdown]
# Create a regression plot using lmplot() for the same data.

# %%
sns.lmplot(data=df,
         x="mpg",
         y="hp")

# Display the plot
plt.show()

# %% [markdown]
# ## 6. Plotting multiple variables  using 'hue'

# %%
sns.lmplot(data=df,
         x="mpg",
         y="hp",
         hue='origin')

# Display the plot
plt.show()

# %% [markdown]
# ## 7. Facetting multiple regressions (row= , col= )

# %% [markdown]
# lmplot() allows us to facet the data across multiple rows and columns.
#
# In the previous plot, the multiple lines were difficult to read in one plot.
#
# We can try creating multiple plots by any columns to see if that is a more useful visualization.

# %%
sns.lmplot(data=df,
         x="mpg",
         y="hp",
         row='origin')

# Display the plot
plt.show()

# %%
sns.lmplot(data=df,
         x="mpg",
         y="hp",
         col='origin')

# Display the plot
plt.show()
